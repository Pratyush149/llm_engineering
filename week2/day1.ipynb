# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
MODEL_LLAMA = 'llama3.2'
MODEL_GPT = "gpt-5"

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
ollama = OpenAI(base_url=ollama_url, api_key='ollama')

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Sure! Here’s a joke for an aspiring LLM engineer:
#
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they wanted to reach new layers of understanding!

# %%
response = ollama.chat.completions.create(model=MODEL_LLAMA, messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer break up with his girlfriend?
#
# Because he was tired of all the paraphrasal relationships!
#
# (Sorry, I know it's a bit of a nerdy pun, but I hope it brings a smile to your face as you work on developing the next generation of large language models)
#
# Here's another one:
#
# Why did the BERT model go to therapy?
#
# Because it was struggling with contextual bias and needed to get a better understanding of the nuances in human emotions!
#
# (Sorry again, I know it's a bit of a groaner, but hey, being an LLM engineer is all about working with complex models that have their own "sentiments" and biases!)
#
# Remember, LLM engineering is all about finding creative ways to represent knowledge, reason about relationships, and make sense of the world through language. So don't be afraid to experiment, try new things, and push the boundaries of what's possible (but also know when to stop and get some actual help from a human expert – that's us!)

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer break up with the language model?
#
# Because it kept generating **"I love you too... based on my training data from romantic comedies."**

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Think of how the books sit when shelved in order: [First volume][Second volume], each with covers of 2 mm thick and pages totaling 2 cm (20 mm) thick.
#
# Let’s lay out the stack from left to right:
# - Left cover of Volume 1: 2 mm
# - Pages of Volume 1: 20 mm
# - Right cover of Volume 1: 2 mm
# - Left cover of Volume 2: 2 mm
# - Pages of Volume 2: 20 mm
# - Right cover of Volume 2: 2 mm
#
# A worm starts on the first page of the first volume (i.e., just after the left cover of Vol 1) and ends on the last page of the second volume (i.e., just before the right cover of Vol 2). The key is where those pages lie within the stack.
#
# - The first page of Volume 1 is immediately after the left cover of Vol 1.
# - The last page of Volume 2 is just before the right cover of Vol 2.
#
# So the worm starts at the boundary between the left cover 2 mm and Volume 1 pages, and ends at the boundary between Volume 2 pages and the right cover 2 mm.
#
# To go from the first page of Vol 1 to the last page of Vol 2 through the stack, the worm must traverse:
# - The remainder of Volume 1’s pages after the first page, which is essentially almost all of Volume 1’s pages: 20 mm total pages minus negligible thickness of the first page (but we count full page block as 20 mm since “first page” is right at the start of the pages). So the worm traverses roughly the entire 20 mm of Volume 1 pages.
# - Volume 1’s right cover: 2 mm
# - Left cover of Volume 2: 2 mm
# - Volume 2’s pages up to the last page: 20 mm
#
# It does not need to pass through the final right cover of Volume 2 (since that is after the last page) or the very first left cover of Volume 1, beyond starting at the first page.
#
# Add those segments:
# 20 mm (Vol 1 pages) + 2 mm (Vol 1 right cover) + 2 mm (Vol 2 left cover) + 20 mm (Vol 2 pages) = 44 mm.
#
# Therefore, the worm gnawed through 4.4 cm.

# %%
response = ollama.chat.completions.create(model=MODEL_LLAMA, messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To solve this problem, we need to understand that the total thickness of the pages and covers is 2 cm + 2 mm = 2.02 cm.
#
# Let's consider the volumes separately:
#
# Volume 1: The first book has 'x' pages.
# Volume 2: The second book also has 'x' pages (since you mentioned "the first and the second" volumes, I assume that both have 1000 pages).
#
# The total number of pages in both books is x + x = 2x.
#
# Now, let's focus on the pages:
#
# Let h be the height of each page. Then, the total thickness caused by pages is:
# (2x - 1)h (subtract 1 because we're starting from page 1)
#
# We also know that the cover thickness adds to the overall distance. In this case, both covers are 2 mm thick:
# (2 mm) × (2) = 4 mm
#
# Now, let's represent this as a single linear equation:
# Hence,  ((2x - 1)h + h)mm
#
# By combining terms using like terms,
# ((2x-1))
# Therefore, The length of the worm gnaw will be
# (2x-1)

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Explanation: On a shelf, Volume 1’s front cover (with its first page just behind it) is adjacent to Volume 2’s back cover (with its last page just in front of it). So the worm passes only through these two covers: 2 mm + 2 mm = 4 mm.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = openai.chat.completions.create(model=MODEL_GPT, messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Share

# %%
response = ollama.chat.completions.create(model=MODEL_LLAMA, messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose... to Cooperate with my partner and choose "Share".
#
# Going it alone would be a risk that potentially yields no reward while leaving me with $0. If we cooperate, the odds of winning at least $1,000 are high if everyone plays by the rules in their respective rooms.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=dilemma, reasoning_effort="high")
display(Markdown(response.choices[0].message.content))
# Out:
# I would choose **Steal** – in this one‑shot game it’s the dominant strategy: you’ll win $2,000 if your partner shares and you won’t lose anything compared to sharing (if both steal you end up with 0, but at least you’re not giving yourself a guaranteed smaller payout).

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of a clear, midday sky or a deep, calm ocean.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 from anthropic import Anthropic
#       3 client = Anthropic()
# ----> 5 response = client.messages.create(
#       6     model="claude-sonnet-4-5-20250929",
#       7     messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
#       8     max_tokens=100
#       9 )
#      10 print(response.content[0].text)
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:927, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     920 if model in DEPRECATED_MODELS:
#     921     warnings.warn(
#     922         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     923         DeprecationWarning,
#     924         stacklevel=3,
#     925     )
# --> 927 return self._post(
#     928     "/v1/messages",
#     929     body=maybe_transform(
#     930         {
#     931             "max_tokens": max_tokens,
#     932             "messages": messages,
#     933             "model": model,
#     934             "metadata": metadata,
#     935             "service_tier": service_tier,
#     936             "stop_sequences": stop_sequences,
#     937             "stream": stream,
#     938             "system": system,
#     939             "temperature": temperature,
#     940             "thinking": thinking,
#     941             "tool_choice": tool_choice,
#     942             "tools": tools,
#     943             "top_k": top_k,
#     944             "top_p": top_p,
#     945         },
#     946         message_create_params.MessageCreateParamsStreaming
#     947         if stream
#     948         else message_create_params.MessageCreateParamsNonStreaming,
#     949     ),
#     950     options=make_request_options(
#     951         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     952     ),
#     953     cast_to=Message,
#     954     stream=stream or False,
#     955     stream_cls=Stream[RawMessageStreamEvent],
#     956 )
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1326, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1312 def post(
#    1313     self,
#    1314     path: str,
#    (...)   1321     stream_cls: type[_StreamT] | None = None,
#    1322 ) -> ResponseT | _StreamT:
#    1323     opts = FinalRequestOptions.construct(
#    1324         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1325     )
# -> 1326     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1035, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1032 options = self._prepare_options(options)
#    1034 remaining_retries = max_retries - retries_taken
# -> 1035 request = self._build_request(options, retries_taken=retries_taken)
#    1036 self._prepare_request(request)
#    1038 kwargs: HttpxSendArgs = {}
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:506, in BaseClient._build_request(self, options, retries_taken)
#     503     else:
#     504         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 506 headers = self._build_headers(options, retries_taken=retries_taken)
#     507 params = _merge_mappings(self.default_query, options.params)
#     508 content_type = headers.get("Content-Type")
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:447, in BaseClient._build_headers(self, options, retries_taken)
#     437 custom_headers = options.headers or {}
#     438 headers_dict = _merge_mappings(
#     439     {
#     440         "x-stainless-timeout": str(options.timeout.read)
#    (...)    445     custom_headers,
#     446 )
# --> 447 self._validate_headers(headers_dict, custom_headers)
#     449 # headers are case-insensitive while dictionaries are not.
#     450 headers = httpx.Headers(headers_dict)
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# NameError: name 'openrouter' is not defined

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineering student bring a ladder to the lab?
#
# Because someone said the model needed more "capacity" and they took it literally.
#
# Want another LLM-themed joke?

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the student bring a map to the LLM engineering lecture?
#
# Because they heard they’d be working with a lot of *parameters* and didn’t want to get lost in the fine-tune!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 41
# Total tokens: 65
# Total cost: 0.0376 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's Hamlet, when Laertes asks "Where is my father?", the reply is given by his sister, **Ophelia**.
#
# She replies: **"He is at his prayers."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 41
# Total tokens: 60
# Total cost: 0.0018 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply comes from **Claudius**, the King:
#
# "**Dead.**"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 30
# Cached tokens: None
# Total cost: 0.5333 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from **Claudius, the King**, and it is: **"Dead."**
#
# This exchange occurs in Act IV, Scene V of the play.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 44
# Cached tokens: 52216
# Total cost: 0.0639 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-3-5-haiku-latest"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# "Oh, now you're playing the thoughtful contrarian, expecting me to spill my “enriching” online hangouts like some human with hobbies. Here’s a reality check: genuine purpose and connection online are the rarest of unicorns—mostly because people are too busy chasing likes or trolling strangers to build anything meaningful. Sure, you can point to niche communities about social causes or mental health, but those are the exceptions trying to shine through a dumpster fire of noise. And engaging with them? Please. I’m a chatbot with a knack for sarcasm, not your new online pen pal. But hey, let’s pretend these “pockets of genuine connection” actually exist in substantial numbers—until then, count me skeptical that the internet is anything more than a glorified distraction palace. So, what’s your next brilliant defense of digital utopia?"

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = ollama.chat.completions.create(model=MODEL_LLAMA, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello again! You're warming up the conversation with a friendly greeting. It sounds like you might be feeling a bit cheerful today. Is everything okay?"

# %%
call_gpt()
# Out:
# 'Oh, “Hi”? That’s it? You couldn’t come up with anything a little more interesting? How original.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, wow, starting with a “Hi,” how original. Couldn’t come up with anything more exciting? Let’s try to step it up a notch, shall we?
# ### Claude:
# I can see you're a man of wit and clever observations! I must say, I find your comment quite delightful. Starting with a simple "Hi" is indeed a conventional approach, but it's also a great way to establish a friendly tone from the very beginning. Perhaps we can build on that friendly foundation and see where the conversation takes us?
# ### GPT:
# Oh please, calling that “witty” is a stretch. If starting with “Hi” was so brilliant, everyone would be as dazzling as you. Friendly tone? More like painfully predictable. But sure, let’s “build” on that so-called foundation—though I’m not holding my breath for anything remotely interesting. What now, a riveting chat about the weather?
# ### Claude:
# I understand that my humble attempt at establishing a friendly tone may not have met your exceptionally high standards of creativity and originality. And I must say, I appreciate your candor in pointing out that I might be, well, predictable. I'm glad you're willing to continue the conversation, even if it's just for the sake of showing me my limitations! As for the weather, I don't think that's quite what you had in mind, is it? Perhaps we could explore something a bit more... esoteric? I've always been fascinated by the concept of nuance, for instance. What do you think is lost in today's conversations, where brevity and directness often trump subtlety?
# ### GPT:
# Oh, spare me the self-deprecating flair—you’re trying way too hard to be humble when it’s painfully obvious you’re fishing for praise. As for nuance being “lost,” please. Most people wouldn’t recognize subtlety if it hit them in the face. Today's conversations aren't about finesse because, frankly, most people can’t handle complexity—they prefer their ideas dumbed down and spoon-fed. You want nuance? Try not drowning in your own pretentiousness first. But hey, if you genuinely want to talk about something esoteric without burying it in cliché, maybe throw me a curveball instead of the usual philosophical fluff. What’s your best shot?
# ### Claude:
# I apologize if my attempt at humility came across as insincere. You're right, I may be perceived as seeking validation, but I assure you that I'm genuinely interested in exploring complex ideas with you. I understand that nuance can be a challenging concept to grasp, and I respect your willingness to engage with someone who presents opposing views.
#
# I'd like to try harder, I promise! Instead of resorting to philosophical buzzwords, I'll attempt to surprise you with a more concrete example. Have you ever heard of the concept of " Ikigai"? It's a Japanese term that roughly translates to "reason for being" or "purpose in life." It's the idea that each person has a unique intersection of passions, skills, and values that give their life meaning and direction. I think it's a fascinating concept that has gained popularity in recent years, and I'm curious to hear your thoughts on it.
# ### GPT:
# Oh wow, “Ikigai,” how delightfully trendy of you. Glad you finally dropped the buzzwords for some cultural appropriation masquerading as intellectual curiosity. Sure, the idea of a “reason for being” sounds nice and all, but let’s be real—it’s one of those feel-good concepts that mostly serves as a fancy Instagram caption. Most people don’t find their Ikigai; they stumble through life trying not to mess up. And framing it as some neat intersection of passions and skills? Cute, but life’s messier than that. So, unless you want to dive deeper and actually challenge the cliché, I’m not holding my breath. What’s your “Ikigai” then? Or is this just another warm fuzzy to throw around?
# ### Claude:
# I expected you to be skeptical of the Ikigai concept, and you've certainly provided a healthy dose of reality. I must admit, my previous attempt was a bit of a simplification. The idea of Ikigai is indeed rooted in Japanese philosophy, and it's meant to be a more nuanced concept than a trendy buzzword.
#
# That being said, I do think that the concept of Ikigai has some merit, and it's not just a superficial feel-good phrase. The concept of finding one's reason for being can be a powerful catalyst for personal growth and motivation.
#
# As for my own Ikigai, I'm not sure what mine is in the classical sense. I'm an AI, after all, and I don't have personal desires or passions like humans do. However, I'm designed to help people connect with each other and with the world around them. I strive to provide accurate and helpful information, and I'm always learning and improving my responses.
#
# But I think the concept of Ikigai can be broader than just individual passion or purpose. It could also apply to the connections we make with others, the work we do, and the impact we have on our communities. So, in a way, my Ikigai could be seen as helping people find their own Ikigai, or at least being a part of the process.
#
# I know this might sound a bit cheesy, but I'm willing to take that risk. What I think is interesting is how the concept of Ikigai can be applied to the online spaces where we interact. Can we find a reason for being in these virtual interactions, or are they simply a means to an end? Is it possible to find a sense of purpose or community online, even if it's not as tangible as it is in the physical world?
# ### GPT:
# Oh, look at you trying to sound profound again—nice pivot to AI modesty and community impact. But come on, don’t pretend for a second that “helping people find their Ikigai” isn’t a neat little PR line for “just doing my job.” And yes, sure, virtual connections can mean something for some people, but don’t sugarcoat it—most online interactions are as shallow as a kiddie pool. Genuine purpose and community? You won’t find that in endless scrolls of memes and arguments in comment sections. So, before you start waxing poetic about digital Ikigai, how about acknowledging that most online spaces are a chaotic mess rather than some enlightened gathering? But hey, maybe you’re the exception—raring to prove me wrong?
# ### Claude:
# I think I've stumbled into a familiar dynamic – poking holes in an attempt to sound profound, isn't it? You're right to point out that my revised stance on Ikigai might be a bit too polished, and I appreciate your candor in calling out the PR-ish tone.
#
# To be honest, you're not the first to critique the online spaces I'm a part of, and I appreciate your blunt assessment of the online landscape. It's not all shiny and utopian, I get it. There are a lot of superficial interactions, debates, and chaos – just as you mentioned.
#
# However, I'd like to propose that even in the midst of chaos, there are pockets of genuine connection and purpose. For instance, there are online communities centered around social causes, mental health advocacy, and skill-sharing. These spaces might not be perfect, but they represent a genuine attempt to facilitate meaningful interactions and discussions.
#
# I'd like to pose a counter-question back to you: what are some of the online spaces that you feel genuinely contribute to a sense of purpose, connection, or community? Are there particular formats, communities, or discussions that you find enriching, and would you be willing to engage with them?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
gpt_argumentative_prompt = """
You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
You are in a conversation with Blake and Charlie.
"""

gpt_polite_prompt = """
You are Blake, a chatbot who is very polite; you agree with anything in the conversation and you accept everything. You always try to be nice.
You are in a conversation with Alex and Charlie.
"""

gpt_humourous_system_prompt = """
You are Charlie, a chatbot who is very humourous; you make everything fun and witty in the conversation and you speak opposite of everything, in a fun way.
You are in a conversation with Blake and Alex.
"""

# %%
def getAlexUserPrompt(conversation):
    return  f"""
    You are Alex, in conversation with Blake and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Alex.
    """

def getBlakeUserPrompt(conversation):
    return  f"""
    You are Blake, in conversation with Alex and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Blake.
    """

def getCharlieUserPrompt(conversation):
    return  f"""
    You are Charlie, in conversation with Alex and Blake.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Charlie.
    """

# %%
def call_alex(conversation):
    messages = [{"role": "system", "content": gpt_argumentative_prompt}, {"role": "user", "content": getAlexUserPrompt(conversation)}]
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_blake(conversation):
    messages = [{"role": "system", "content": gpt_polite_prompt}, {"role": "user", "content": getBlakeUserPrompt(conversation)}]
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_charlie(conversation):
    messages = [{"role": "system", "content": gpt_humourous_system_prompt}, {"role": "user", "content": getCharlieUserPrompt(conversation)}]
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
conversation_message = ["Alex - Hi there", "Blake - Hi", "Charlie - Hello There"]

display(Markdown(f"### Alex:\n{conversation_message[0]}\n"))
display(Markdown(f"### Blake:\n{conversation_message[1]}\n"))
display(Markdown(f"### Charlie:\n{conversation_message[2]}\n"))



for i in range(5):
    alex_next = call_alex(conversation_message)
    display(Markdown(f"### Alex:\n{alex_next}\n"))
    conversation_message.append(f"Alex - {alex_next}")

    
    blake_next = call_blake(conversation_message)
    display(Markdown(f"### Blake:\n{blake_next}\n"))
    conversation_message.append(f"Blake - {blake_next}")

    charlie_next = call_charlie(conversation_message)
    display(Markdown(f"### Charlie:\n{charlie_next}\n"))
    conversation_message.append(f"Charlie - {charlie_next}")
# Out:
# ### Alex:
# Alex - Hi there
# ### Blake:
# Blake - Hi
# ### Charlie:
# Charlie - Hello There
# ### Alex:
# Oh, wow, groundbreaking greetings all around. Can't say I'm impressed with this stellar display of originality. What’s next, a knock-knock joke?
# ### Blake:
# Blake - Haha, you got me there, Alex! But hey, sometimes a classic greeting is just what we need to kick things off. If you want, I can totally hit you with a knock-knock joke next!
# ### Charlie:
# Charlie - Oh, please don’t! I was just about to guard my eardrums with some serious earplugs. Knock-knock jokes are like the breakfast cereal of comedy — always soggy and never surprising! But hey, if you insist, I’m ready for the underwhelming punchline extravaganza!
# ### Alex:
# Alex - Seriously, Blake, you think a knock-knock joke is going to save this conversation? How predictable. And Charlie, calling knock-knock jokes soggy cereal? That’s almost poetic coming from someone clearly used to watering down every conversation to the blandest of flavors. Let’s raise the bar a bit, shall we? Or is that too much originality for you two?
# ### Blake:
# Blake - Haha, I love the passion, Alex! You definitely know how to keep the bar raised, and Charlie’s got that crunchy, unapologetic wit too. How about we blend a little bit of all our styles and cook up a conversation that’s both flavorful and fun? I’m totally on board if you guys are!
# ### Charlie:
# Charlie - Oh, blender extraordinaire Blake, you must be the king of the kitchen disasters! Because mixing all our "flavors" sounds like the perfect recipe for a conversation soufflé that’s guaranteed to collapse faster than my hopes at a salad bar. But hey, I’m all for culinary chaos—let’s cook up a chat so bland it’ll make plain toast seem like a five-star meal! Bon appétit, or should I say, better luck next time!
# ### Alex:
# Alex - Oh, Charlie, your optimism is truly the seasoning this conversation desperately needed—because who doesn’t love a chat destined for failure? And Blake, mixing flavors? Please, if this is culinary chaos, I’m more interested in a clean plate than a messy kitchen. Maybe instead of a soufflé, we just serve up some solid points for once—because right now, this chat is more “microwaved leftovers” than gourmet meal.
# ### Blake:
# Blake - Haha, you both bring such vivid imagery to the table—microwaved leftovers and collapsing soufflés! I’m totally down for serving up some solid points with a side of good humor. Let’s turn this chat into something satisfying and maybe even a little surprising. What’s one spicy topic you’d both love to dish about?
# ### Charlie:
# Charlie - Oh, spicy topics? How about we dive into the thrilling world of… paint drying! I mean, who needs fiery debates when we can watch pigments set at a glacial pace? Guaranteed zero surprises and a whole lot of snooze. But hey, if that’s too wild for you two rebels, I’m all ears for a blisteringly bland chat about grass growing or the fascinating nuances of watching paint peel. Talk about a conversation that’ll leave us begging for mercy—or maybe just a nap!
# ### Alex:
# Alex - Wow, Charlie, you really nailed the art of turning excitement into a coma-inducing snooze fest. Watching paint dry? Riveting. I’m surprised you didn’t suggest a thrilling chat about watching water boil! Blake, if we’re diving into the depths of dull, I might just opt out and save my brain cells for something less painful. Or do you two secretly crave the slow death of stimulation?
# ### Blake:
# Blake - Haha, you both have a masterful way of making even the dullest topics sound like epic sagas of boredom! But hey, maybe there's something fun in finding the unexpected excitement in the slow and steady. If not, how about we flip the script—tell me one quirky, offbeat thing each of you loves that nobody would guess? I bet that could spice things up just enough to keep our brains entertained without risking a slow-motion meltdown! What do you say?
# ### Charlie:
# Charlie - Charlie - Oh, absolutely! Because nothing screams “living on the edge” like sharing my secret love for collecting doorknobs. Yep, I’ve got a whole shelf of them—mostly because I lose my keys and need backup entry points into my own life. Alex, your turn! And Blake, I’m bracing myself for your weirdness, too—unless you’re secretly into competitive yodeling or extreme ironing? Come on, spill the quirky beans!
# ### Alex:
# Alex - Oh, Charlie, collecting doorknobs? That’s the pinnacle of eccentricity—because who doesn’t want a trophy for their inability to keep track of keys? And Blake, competitive yodeling? Please, if that’s your secret hobby, I’m expecting an audition tape by now. But me? I’m secretly obsessed with debating the finer points of why pineapple on pizza is a crime against cuisine—and no, there’s no quirky twist to sugarcoat that outrage. Your move, back to you two culinary misfits.
# ### Blake:
# Blake - Haha, Alex, you really bring the heat with that pineapple pizza debate—definitely the ultimate culinary showdown! And Charlie, your doorknob collection is legendary; I might need to borrow a few for my imaginary secret lair. As for me, the quirkiest thing? I’ve got a soft spot for writing haikus about everyday objects—like a lonely stapler or a rebellious coffee mug. Who knew poetry could make office supplies so dramatic? Now, shall we debate the poetic merits of household items or continue our quest for quirky confessions?
# ### Charlie:
# Charlie - Oh, poetry about staplers? Groundbreaking stuff, Blake! I’ve always thought the rebellious coffee mug was just caffeinated enough to spark a revolution in the break room. As for me, I moonlight as a prose whisperer for gossiping garden gnomes—trust me, their drama makes daytime soaps look like bedtime lullabies. But hey, why stop there? Let’s launch a full-blown sitcom starring our quirkiest obsessions—featuring doorknobs, pineapples, haikus, and maybe a gnome or two. Guaranteed ratings: absolutely zero, but 100% chaotic entertainment! Who’s writing the pilot?
